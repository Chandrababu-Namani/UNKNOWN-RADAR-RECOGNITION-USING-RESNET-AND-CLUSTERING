# %% [markdown]
# START

# %%
import numpy as np
KK_signals = np.load('D:\\Projects\\Major_Project\\New\\KK_signals.npy', mmap_mode='r')
UU_signals = np.load('D:\\Projects\\Major_Project\\New\\UU_signals.npy', mmap_mode='r')

# %%
signals1=list(KK_signals[::50][:500])
signals2=UU_signals[::50][:500]
for i in signals2:
    signals1.append(i)
signals=signals1
# Out:
# 1000

# %%
import tkinter as tk
from tkinter import ttk, messagebox
import tensorflow as tf
from tensorflow.keras.models import load_model
import joblib
import numpy as np

classes = ['32PSK', '16APSK', '32QAM', 'FM', 'GMSK', '32APSK', 'OQPSK', '8ASK', 'BPSK', '8PSK', 'AM-SSB-SC', '4ASK']

# Load the pre-trained models
model = load_model("D:\\Projects\\Major_Project\\New\\model_high_SNR_new_10_labels.h5")
kmeans = joblib.load('D:\\Projects\\Major_Project\\New\\kmeans_model.joblib')

def extract_features():
    index = int(entry.get())
    try:
        global Input_signal, new_signal, features
        Input_signal = signals[index]
        new_signal = tf.expand_dims(Input_signal, 0)
        features = model.predict(new_signal)
        features_label.config(text=f"Signal features extracted")
    except Exception as e:
        messagebox.showerror("Error", f"Invalid input: {e}")

def recognize_signal():
    try:
        new_data = features.reshape(1, -1)
        predicted_cluster = kmeans.predict(new_data)
        clas = np.argmax(features, axis=1)
        if predicted_cluster[0] == 0:
            result = " It is a Known signal \n" + " Category: " + str(classes[clas[0]])
            result_label.config(text=result, foreground='green',background="white")
        else:
            result = """  !THREAT IDENTIFIED!\n It is an Unknown signal"""
            result_label.config(text=result, foreground='red',background="white")           
        
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred: {e}")

def check_input():
    if entry.get():
        check_label.config(text="Signal is identified", foreground='white')
    else:
        check_label.config(text="Please enter the index of the signal", foreground='red')

# Create the main window
root = tk.Tk()
root.title("Radar Signal Recognition")
root.geometry("1000x800")
root.configure(bg='#34495e')  # Background color

# Define styles
style = ttk.Style()
style.configure('TLabel', font=('Helvetica', 14), background='#34495e', foreground='white')  # Text color
style.configure('TButton', font=('Helvetica', 14), padding=10, background='#2ecc71', foreground='black')  # Button color
style.configure('TEntry', font=('Helvetica', 14), background='white')  # Entry widget color

# Create a frame for the title
title_frame = tk.Frame(root, bg='#34495e')
title_frame.pack(pady=20)

# Title label
title_label = ttk.Label(title_frame, text="Radar Signal Recognition", font=('Helvetica', 24, 'bold'))
title_label.pack()

# Create a frame to hold left and right frames
content_frame = tk.Frame(root, bg='#34495e')
content_frame.pack(fill=tk.BOTH, expand=True, padx=20, pady=20)

# Create frames for left and right portions
left_frame = tk.Frame(content_frame, bg='#34495e')
left_frame.pack(side=tk.LEFT, fill=tk.BOTH, expand=True, padx=20, pady=20)

right_frame = tk.Frame(content_frame, bg='#34495e')
right_frame.pack(side=tk.RIGHT, fill=tk.BOTH, expand=True, padx=20, pady=20)

# Left frame content
info_text = """This Radar Signal Recognizer is designed to identify various types of signals. 
The input signal has a shape of 1024x2. It recognizes signals which are known and unknown to the model.

Known Signal categories: 32PSK, 16APSK, 32QAM, FM, GMSK, 32APSK, OQPSK, 8ASK, 8PSK

The model can recognize unknown signals with 100% accuracy. If a signal is unknown, it will be displayed as 'Unknown'
If the signal is one of the known types, the model will correctly identify and categorize it.

Working Process:

1. Enter the Signal Index[0-999]:
   - The list is organized such that the known signals are in the first half.
2. Press the 'Check Signal' Button:
   - This checks if the signal is identified by the system.
   - If the system displays 'Signal is identified', you can proceed to the next step.
3. Press the 'Extract Features' Button:
   - This extracts the features from the trained model.
4. Press the 'Recognize Signal' Button:
   - This recognizes and categorizes the signal.
"""

info_label = ttk.Label(left_frame, text=info_text, font=('Helvetica', 14), wraplength=800, justify=tk.LEFT)
info_label.pack(pady=10)

# Right frame content
input_label = ttk.Label(right_frame, text="Input Signal Index", font=('Helvetica', 14))
input_label.pack(pady=10)

entry = ttk.Entry(right_frame, width=30)
entry.pack(pady=10,ipady=5)

check_button = ttk.Button(right_frame, text="Check Signal", command=check_input,width=14)
check_button.pack(pady=10)

check_label = ttk.Label(right_frame, text="", font=('Helvetica', 14))
check_label.pack(pady=10)

extract_button = ttk.Button(right_frame, text="Extract Features", command=extract_features,width=14)
extract_button.pack(pady=20)

features_label = ttk.Label(right_frame, text="", font=('Helvetica', 14))
features_label.pack(pady=20)

recognize_button = ttk.Button(right_frame, text="Recognize Signal", command=recognize_signal)
recognize_button.pack(pady=20)

result_label = ttk.Label(right_frame, text="", font=('Helvetica', 14, 'bold'))
result_label.pack(pady=20)

# Run the application
root.mainloop()
# Out:
# ...
# 1/1 [==============================] - 0s 31ms/step

# %% [markdown]
# END

# %%
len(signals1)
# Out:
# 1000

# %%
import tkinter as tk
from tkinter import ttk, messagebox
import tensorflow as tf
from tensorflow.keras.models import load_model
import joblib
import numpy as np

classes = ['32PSK', '16APSK', '32QAM', 'FM', 'GMSK', '32APSK', 'OQPSK', '8ASK', 'BPSK', '8PSK', 'AM-SSB-SC', '4ASK']

# Load the pre-trained models
model = load_model("D:\\Projects\\Major_Project\\New\\model_high_SNR_new_10_labels.h5")
kmeans = joblib.load('D:\\Projects\\Major_Project\\New\\kmeans_model.joblib')

def extract_features():
    index = int(entry.get())
    try:
        global Input_signal, new_signal, features
        Input_signal = signals[index]
        new_signal = tf.expand_dims(Input_signal, 0)
        features = model.predict(new_signal)
        features_label.config(text=f"Signal features extracted.")
    except Exception as e:
        messagebox.showerror("Error", f"Invalid input: {e}")

def recognize_signal():
    try:
        new_data = features.reshape(1, -1)
        predicted_cluster = kmeans.predict(new_data)
        clas = np.argmax(features, axis=1)
        if predicted_cluster[0] == 0:
            result = "It is a Known signal\n" + "Category: " + str(classes[clas[0]])
        else:
            result = "It is an Unknown signal"
        result_label.config(text=result)
    except Exception as e:
        messagebox.showerror("Error", f"An error occurred: {e}")

def check_input():
    if entry.get():
        check_label.config(text="Signal is identified", foreground='green')
    else:
        check_label.config(text="Please enter the index of the signal", foreground='red')

# Create the main window
root = tk.Tk()
root.title("Radar Signal Recognition")
root.geometry("1000x800")
root.configure(bg='#34495e')  # Background color

# Define styles
style = ttk.Style()
style.configure('TLabel', font=('Helvetica', 14), background='#34495e', foreground='white')  # Text color
style.configure('TButton', font=('Helvetica', 14), padding=10, background='#2ecc71', foreground='black')  # Button color
style.configure('TEntry', font=('Helvetica', 14), background='white')  # Entry widget color

# Create frames for left and right portions
left_frame = tk.Frame(root, bg='#34495e')
left_frame.pack(side=tk.LEFT, fill=tk.BOTH, expand=True, padx=20, pady=20)

right_frame = tk.Frame(root, bg='#34495e')
right_frame.pack(side=tk.RIGHT, fill=tk.BOTH, expand=True, padx=20, pady=20)

# Left frame content
title_label = ttk.Label(left_frame, text="Radar Signal Recognition", font=('Helvetica', 18, 'bold'))
title_label.pack(pady=20)

info_text = """This Radar Signal Recognizer is designed to identify various types of signals. 
The input signal has a shape of 1024x2. The recognizer classifies signals into two main categories: 
Known and Unknown.

### Known Signal Types:
- 32PSK
- 16APSK
- 32QAM
- FM
- GMSK
- 32APSK
- OQPSK
- 8ASK
- 8PSK

### Unknown Signals:
- The model recognizes unknown signals with 100% accuracy.
- If a signal is unknown, it will be classified as "Unknown."
- If the signal is known, the model will correctly identify and categorize it.

### Working Process:
1. **Enter the Signal Index:**
   - Input a signal index from 0 to 999.
   - The list is organized such that the known signals are in the first half.
2. **Press the "Check Signal" Button:**
   - This checks if the signal is identified by the system.
   - If the system displays 'Signal is identified', you can proceed to the next step.
3. **Press the "Extract Features" Button:**
   - This extracts the features from the trained model.
4. **Press the "Recognize Signal" Button:**
   - This recognizes and categorizes the signal.

Follow these steps to accurately identify and categorize the radar signals."""

info_label = ttk.Label(left_frame, text=info_text, font=('Helvetica', 14), wraplength=400, justify=tk.LEFT)
info_label.pack(pady=10)

# Right frame content
input_label = ttk.Label(right_frame, text="Input Signal Index:", font=('Helvetica', 14))
input_label.pack(pady=10)

entry = ttk.Entry(right_frame, width=50)
entry.pack(pady=10)

check_button = ttk.Button(right_frame, text="Check Input", command=check_input)
check_button.pack(pady=10)

check_label = ttk.Label(right_frame, text="", font=('Helvetica', 14))
check_label.pack(pady=10)

extract_button = ttk.Button(right_frame, text="Extract Features", command=extract_features)
extract_button.pack(pady=20)

features_label = ttk.Label(right_frame, text="", font=('Helvetica', 14))
features_label.pack(pady=20)

recognize_button = ttk.Button(right_frame, text="Recognize Signal", command=recognize_signal)
recognize_button.pack(pady=20)

result_label = ttk.Label(right_frame, text="", font=('Helvetica', 14, 'bold'))
result_label.pack(pady=20)

# Run the application
root.mainloop()
# Out:
# 1/1 [==============================] - 0s 278ms/step

# %%
len(KK_signals),len(UU_signals)
# Out:
# (45056, 45056)

# %%
signals=KK_signals+UU_signals

# %%
def see(index):
        Input_signal = signals1[index]
        new_signal = tf.expand_dims(Input_signal, 0)

        # Make prediction
        prediction = model.predict(new_signal)
        new_data = prediction.reshape(1, -1)
        predicted_cluster = kmeans.predict(new_data)
        clas = np.argmax(prediction, axis=1)
        if predicted_cluster[0] == 0:
#             result = "It is a Known signal\n" + "Category: " + str(classes[clas[0]])
              return 1
        else: return 0
#             result = "It is an Unknown signal"
u,k=0,0
for i in range(len(signals2)):
    if see(i)==1: k+=1
    else: u+=1
# Out:
# ...
# 1/1 [==============================] - 0s 22ms/step

# %%
len(signals2)
# Out:
# 500
